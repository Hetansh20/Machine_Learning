# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
col_names= ['sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'class']
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
dataset = pd.read_csv(url, names=col_names)

# %%
dataset
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dataset_knn = dataset.values[:,0:4]
labels = dataset.values[:,-1]

# %%
dataset_knn
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3.0, 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5.0, 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5.0, 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3.0, 1.4, 0.1],
#        [4.3, 3.0, 1.1, 0.1],
#        [5.8, 4.0, 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1.0, 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5.0, 3.0, 1.6, 0.2],
#        [5.0, 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.0, 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3.0, 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5.0, 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5.0, 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3.0, 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5.0, 3.3, 1.4, 0.2],
#        [7.0, 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4.0, 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1.0],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5.0, 2.0, 3.5, 1.0],
#        [5.9, 3.0, 4.2, 1.5],
#        [6.0, 2.2, 4.0, 1.0],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3.0, 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1.0],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4.0, 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3.0, 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3.0, 5.0, 1.7],
#        [6.0, 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1.0],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1.0],
#        [5.8, 2.7, 3.9, 1.2],
#        [6.0, 2.7, 5.1, 1.6],
#        [5.4, 3.0, 4.5, 1.5],
#        [6.0, 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3.0, 4.1, 1.3],
#        [5.5, 2.5, 4.0, 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3.0, 4.6, 1.4],
#        [5.8, 2.6, 4.0, 1.2],
#        [5.0, 2.3, 3.3, 1.0],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3.0, 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3.0, 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6.0, 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3.0, 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3.0, 5.8, 2.2],
#        [7.6, 3.0, 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2.0],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3.0, 5.5, 2.1],
#        [5.7, 2.5, 5.0, 2.0],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3.0, 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6.0, 2.2, 5.0, 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2.0],
#        [7.7, 2.8, 6.7, 2.0],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6.0, 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3.0, 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3.0, 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2.0],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3.0, 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6.0, 3.0, 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3.0, 5.2, 2.3],
#        [6.3, 2.5, 5.0, 1.9],
#        [6.5, 3.0, 5.2, 2.0],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3.0, 5.1, 1.8]], dtype=object)

# %%
import math

# %%
def distance(x1,x2):
  distances = 0.0
  for i in range(len(x1)):
    distances += (x1[i] - x2[i]) ** 2
  return (math.sqrt(distances))

# %%
testing_data = dataset.values[101, 0:4]

# %%
distance_cumm = []
for i in range(len(dataset_knn)):
  distance_cumm.append([distance(dataset_knn[i], testing_data), labels[i]])

# %%
distance_cumm
# Out:
# [[0.3872983346207423, 'Iris-setosa'],
#  [0.6782329983125268, 'Iris-setosa'],
#  [0.7810249675906655, 'Iris-setosa'],
#  [0.8774964387392128, 'Iris-setosa'],
#  [0.5000000000000003, 'Iris-setosa'],
#  [0.5385164807134504, 'Iris-setosa'],
#  [0.8124038404635967, 'Iris-setosa'],
#  [0.44721359549995826, 'Iris-setosa'],
#  [1.140175425099138, 'Iris-setosa'],
#  [0.6557438524302001, 'Iris-setosa'],
#  [0.3605551275463992, 'Iris-setosa'],
#  [0.6403124237432855, 'Iris-setosa'],
#  [0.7874007874011815, 'Iris-setosa'],
#  [1.272792206135786, 'Iris-setosa'],
#  [0.8062257748298548, 'Iris-setosa'],
#  [1.0440306508910553, 'Iris-setosa'],
#  [0.5385164807134504, 'Iris-setosa'],
#  [0.3464101615137761, 'Iris-setosa'],
#  [0.547722557505166, 'Iris-setosa'],
#  [0.5099019513592788, 'Iris-setosa'],
#  [0.282842712474619, 'Iris-setosa'],
#  [0.42426406871192923, 'Iris-setosa'],
#  [0.984885780179611, 'Iris-setosa'],
#  [0.3872983346207422, 'Iris-setosa'],
#  [0.7483314773547887, 'Iris-setosa'],
#  [0.6082762530298221, 'Iris-setosa'],
#  [0.4123105625617664, 'Iris-setosa'],
#  [0.30000000000000016, 'Iris-setosa'],
#  [0.30000000000000016, 'Iris-setosa'],
#  [0.761577310586391, 'Iris-setosa'],
#  [0.7071067811865479, 'Iris-setosa'],
#  [0.0, 'Iris-setosa'],
#  [0.7874007874011809, 'Iris-setosa'],
#  [0.8366600265340758, 'Iris-setosa'],
#  [0.6557438524302001, 'Iris-setosa'],
#  [0.5744562646538031, 'Iris-setosa'],
#  [0.31622776601683783, 'Iris-setosa'],
#  [0.6557438524302001, 'Iris-setosa'],
#  [1.1135528725660044, 'Iris-setosa'],
#  [0.36055512754639957, 'Iris-setosa'],
#  [0.46904157598234325, 'Iris-setosa'],
#  [1.4387494569938162, 'Iris-setosa'],
#  [1.058300524425836, 'Iris-setosa'],
#  [0.46904157598234325, 'Iris-setosa'],
#  [0.6403124237432851, 'Iris-setosa'],
#  [0.7348469228349538, 'Iris-setosa'],
#  [0.5477225575051664, 'Iris-setosa'],
#  [0.8544003745317538, 'Iris-setosa'],
#  [0.37416573867739455, 'Iris-setosa'],
#  [0.4690415759823433, 'Iris-setosa'],
#  [3.7202150475476548, 'Iris-versicolor'],
#  [3.3541019662496847, 'Iris-versicolor'],
#  [3.8871583451153624, 'Iris-versicolor'],
#  [2.877498913987632, 'Iris-versicolor'],
#  [3.519943181359608, 'Iris-versicolor'],
#  [3.2031234756093934, 'Iris-versicolor'],
#  [3.5355339059327378, 'Iris-versicolor'],
#  [2.202271554554524, 'Iris-versicolor'],
#  [3.4799425282610623, 'Iris-versicolor'],
#  [2.6999999999999997, 'Iris-versicolor'],
#  [2.545584412271571, 'Iris-versicolor'],
#  [2.98496231131986, 'Iris-versicolor'],
#  [2.9, 'Iris-versicolor'],
#  [3.461213659975356, 'Iris-versicolor'],
#  [2.3473389188611002, 'Iris-versicolor'],
#  [3.3451457367355464, 'Iris-versicolor'],
#  [3.2264531609803355, 'Iris-versicolor'],
#  [2.7874719729532704, 'Iris-versicolor'],
#  [3.5057096285916205, 'Iris-versicolor'],
#  [2.6645825188948455, 'Iris-versicolor'],
#  [3.624913792078371, 'Iris-versicolor'],
#  [2.8124722220850464, 'Iris-versicolor'],
#  [3.793415347678132, 'Iris-versicolor'],
#  [3.424908757908742, 'Iris-versicolor'],
#  [3.146426544510455, 'Iris-versicolor'],
#  [3.3181320046074116, 'Iris-versicolor'],
#  [3.7696153649941526, 'Iris-versicolor'],
#  [3.9736632972611052, 'Iris-versicolor'],
#  [3.2893768406797053, 'Iris-versicolor'],
#  [2.2561028345356955, 'Iris-versicolor'],
#  [2.6057628441590763, 'Iris-versicolor'],
#  [2.4919871588754225, 'Iris-versicolor'],
#  [2.6551836094703507, 'Iris-versicolor'],
#  [3.9051248379533265, 'Iris-versicolor'],
#  [3.2202484376209237, 'Iris-versicolor'],
#  [3.286335345030997, 'Iris-versicolor'],
#  [3.6373066958946425, 'Iris-versicolor'],
#  [3.3526109228480423, 'Iris-versicolor'],
#  [2.7874719729532704, 'Iris-versicolor'],
#  [2.80713376952364, 'Iris-versicolor'],
#  [3.1144823004794877, 'Iris-versicolor'],
#  [3.355592347112503, 'Iris-versicolor'],
#  [2.773084924772409, 'Iris-versicolor'],
#  [2.2293496809607953, 'Iris-versicolor'],
#  [2.9376861643136762, 'Iris-versicolor'],
#  [2.8600699292150185, 'Iris-versicolor'],
#  [2.90516780926679, 'Iris-versicolor'],
#  [3.0886890422961, 'Iris-versicolor'],
#  [1.9078784028338915, 'Iris-versicolor'],
#  [2.8319604517012587, 'Iris-versicolor'],
#  [5.047771785649585, 'Iris-virginica'],
#  [3.982461550347975, 'Iris-virginica'],
#  [5.029910535983717, 'Iris-virginica'],
#  [4.453088815642463, 'Iris-virginica'],
#  [4.806245936279167, 'Iris-virginica'],
#  [5.822370651203854, 'Iris-virginica'],
#  [3.427827300200522, 'Iris-virginica'],
#  [5.372150407425317, 'Iris-virginica'],
#  [4.790615826801393, 'Iris-virginica'],
#  [5.371219600798314, 'Iris-virginica'],
#  [4.095119045888653, 'Iris-virginica'],
#  [4.263801121065568, 'Iris-virginica'],
#  [4.583666654546335, 'Iris-virginica'],
#  [3.963584236521283, 'Iris-virginica'],
#  [4.180908992073374, 'Iris-virginica'],
#  [4.369210454990696, 'Iris-virginica'],
#  [4.396589587396122, 'Iris-virginica'],
#  [5.977457653551383, 'Iris-virginica'],
#  [6.220932405998316, 'Iris-virginica'],
#  [3.906404996924922, 'Iris-virginica'],
#  [4.851803788283282, 'Iris-virginica'],
#  [3.8105117766515306, 'Iris-virginica'],
#  [5.937171043518959, 'Iris-virginica'],
#  [3.8496753109840314, 'Iris-virginica'],
#  [4.7148700936505135, 'Iris-virginica'],
#  [5.048762224545736, 'Iris-virginica'],
#  [3.7215588131856787, 'Iris-virginica'],
#  [3.7643060449437424, 'Iris-virginica'],
#  [4.589117562233506, 'Iris-virginica'],
#  [4.830113870293329, 'Iris-virginica'],
#  [5.2697248505021586, 'Iris-virginica'],
#  [5.742821606144492, 'Iris-virginica'],
#  [4.62709412050371, 'Iris-virginica'],
#  [3.9166312055132275, 'Iris-virginica'],
#  [4.352011029397788, 'Iris-virginica'],
#  [5.4972720507539, 'Iris-virginica'],
#  [4.649731175025067, 'Iris-virginica'],
#  [4.364630568559039, 'Iris-virginica'],
#  [3.656501059756444, 'Iris-virginica'],
#  [4.521061822182927, 'Iris-virginica'],
#  [4.752893855326457, 'Iris-virginica'],
#  [4.34856298103178, 'Iris-virginica'],
#  [3.982461550347975, 'Iris-virginica'],
#  [4.996999099459595, 'Iris-virginica'],
#  [4.873397172404482, 'Iris-virginica'],
#  [4.376071297408213, 'Iris-virginica'],
#  [4.014971979976946, 'Iris-virginica'],
#  [4.197618372363071, 'Iris-virginica'],
#  [4.411349000022556, 'Iris-virginica'],
#  [3.915354390090378, 'Iris-virginica']]

# %%
distance_cumm.sort()

# %%
distance_cumm
# Out:
# [[0.0, 'Iris-setosa'],
#  [0.282842712474619, 'Iris-setosa'],
#  [0.30000000000000016, 'Iris-setosa'],
#  [0.30000000000000016, 'Iris-setosa'],
#  [0.31622776601683783, 'Iris-setosa'],
#  [0.3464101615137761, 'Iris-setosa'],
#  [0.3605551275463992, 'Iris-setosa'],
#  [0.36055512754639957, 'Iris-setosa'],
#  [0.37416573867739455, 'Iris-setosa'],
#  [0.3872983346207422, 'Iris-setosa'],
#  [0.3872983346207423, 'Iris-setosa'],
#  [0.4123105625617664, 'Iris-setosa'],
#  [0.42426406871192923, 'Iris-setosa'],
#  [0.44721359549995826, 'Iris-setosa'],
#  [0.46904157598234325, 'Iris-setosa'],
#  [0.46904157598234325, 'Iris-setosa'],
#  [0.4690415759823433, 'Iris-setosa'],
#  [0.5000000000000003, 'Iris-setosa'],
#  [0.5099019513592788, 'Iris-setosa'],
#  [0.5385164807134504, 'Iris-setosa'],
#  [0.5385164807134504, 'Iris-setosa'],
#  [0.547722557505166, 'Iris-setosa'],
#  [0.5477225575051664, 'Iris-setosa'],
#  [0.5744562646538031, 'Iris-setosa'],
#  [0.6082762530298221, 'Iris-setosa'],
#  [0.6403124237432851, 'Iris-setosa'],
#  [0.6403124237432855, 'Iris-setosa'],
#  [0.6557438524302001, 'Iris-setosa'],
#  [0.6557438524302001, 'Iris-setosa'],
#  [0.6557438524302001, 'Iris-setosa'],
#  [0.6782329983125268, 'Iris-setosa'],
#  [0.7071067811865479, 'Iris-setosa'],
#  [0.7348469228349538, 'Iris-setosa'],
#  [0.7483314773547887, 'Iris-setosa'],
#  [0.761577310586391, 'Iris-setosa'],
#  [0.7810249675906655, 'Iris-setosa'],
#  [0.7874007874011809, 'Iris-setosa'],
#  [0.7874007874011815, 'Iris-setosa'],
#  [0.8062257748298548, 'Iris-setosa'],
#  [0.8124038404635967, 'Iris-setosa'],
#  [0.8366600265340758, 'Iris-setosa'],
#  [0.8544003745317538, 'Iris-setosa'],
#  [0.8774964387392128, 'Iris-setosa'],
#  [0.984885780179611, 'Iris-setosa'],
#  [1.0440306508910553, 'Iris-setosa'],
#  [1.058300524425836, 'Iris-setosa'],
#  [1.1135528725660044, 'Iris-setosa'],
#  [1.140175425099138, 'Iris-setosa'],
#  [1.272792206135786, 'Iris-setosa'],
#  [1.4387494569938162, 'Iris-setosa'],
#  [1.9078784028338915, 'Iris-versicolor'],
#  [2.202271554554524, 'Iris-versicolor'],
#  [2.2293496809607953, 'Iris-versicolor'],
#  [2.2561028345356955, 'Iris-versicolor'],
#  [2.3473389188611002, 'Iris-versicolor'],
#  [2.4919871588754225, 'Iris-versicolor'],
#  [2.545584412271571, 'Iris-versicolor'],
#  [2.6057628441590763, 'Iris-versicolor'],
#  [2.6551836094703507, 'Iris-versicolor'],
#  [2.6645825188948455, 'Iris-versicolor'],
#  [2.6999999999999997, 'Iris-versicolor'],
#  [2.773084924772409, 'Iris-versicolor'],
#  [2.7874719729532704, 'Iris-versicolor'],
#  [2.7874719729532704, 'Iris-versicolor'],
#  [2.80713376952364, 'Iris-versicolor'],
#  [2.8124722220850464, 'Iris-versicolor'],
#  [2.8319604517012587, 'Iris-versicolor'],
#  [2.8600699292150185, 'Iris-versicolor'],
#  [2.877498913987632, 'Iris-versicolor'],
#  [2.9, 'Iris-versicolor'],
#  [2.90516780926679, 'Iris-versicolor'],
#  [2.9376861643136762, 'Iris-versicolor'],
#  [2.98496231131986, 'Iris-versicolor'],
#  [3.0886890422961, 'Iris-versicolor'],
#  [3.1144823004794877, 'Iris-versicolor'],
#  [3.146426544510455, 'Iris-versicolor'],
#  [3.2031234756093934, 'Iris-versicolor'],
#  [3.2202484376209237, 'Iris-versicolor'],
#  [3.2264531609803355, 'Iris-versicolor'],
#  [3.286335345030997, 'Iris-versicolor'],
#  [3.2893768406797053, 'Iris-versicolor'],
#  [3.3181320046074116, 'Iris-versicolor'],
#  [3.3451457367355464, 'Iris-versicolor'],
#  [3.3526109228480423, 'Iris-versicolor'],
#  [3.3541019662496847, 'Iris-versicolor'],
#  [3.355592347112503, 'Iris-versicolor'],
#  [3.424908757908742, 'Iris-versicolor'],
#  [3.427827300200522, 'Iris-virginica'],
#  [3.461213659975356, 'Iris-versicolor'],
#  [3.4799425282610623, 'Iris-versicolor'],
#  [3.5057096285916205, 'Iris-versicolor'],
#  [3.519943181359608, 'Iris-versicolor'],
#  [3.5355339059327378, 'Iris-versicolor'],
#  [3.624913792078371, 'Iris-versicolor'],
#  [3.6373066958946425, 'Iris-versicolor'],
#  [3.656501059756444, 'Iris-virginica'],
#  [3.7202150475476548, 'Iris-versicolor'],
#  [3.7215588131856787, 'Iris-virginica'],
#  [3.7643060449437424, 'Iris-virginica'],
#  [3.7696153649941526, 'Iris-versicolor'],
#  [3.793415347678132, 'Iris-versicolor'],
#  [3.8105117766515306, 'Iris-virginica'],
#  [3.8496753109840314, 'Iris-virginica'],
#  [3.8871583451153624, 'Iris-versicolor'],
#  [3.9051248379533265, 'Iris-versicolor'],
#  [3.906404996924922, 'Iris-virginica'],
#  [3.915354390090378, 'Iris-virginica'],
#  [3.9166312055132275, 'Iris-virginica'],
#  [3.963584236521283, 'Iris-virginica'],
#  [3.9736632972611052, 'Iris-versicolor'],
#  [3.982461550347975, 'Iris-virginica'],
#  [3.982461550347975, 'Iris-virginica'],
#  [4.014971979976946, 'Iris-virginica'],
#  [4.095119045888653, 'Iris-virginica'],
#  [4.180908992073374, 'Iris-virginica'],
#  [4.197618372363071, 'Iris-virginica'],
#  [4.263801121065568, 'Iris-virginica'],
#  [4.34856298103178, 'Iris-virginica'],
#  [4.352011029397788, 'Iris-virginica'],
#  [4.364630568559039, 'Iris-virginica'],
#  [4.369210454990696, 'Iris-virginica'],
#  [4.376071297408213, 'Iris-virginica'],
#  [4.396589587396122, 'Iris-virginica'],
#  [4.411349000022556, 'Iris-virginica'],
#  [4.453088815642463, 'Iris-virginica'],
#  [4.521061822182927, 'Iris-virginica'],
#  [4.583666654546335, 'Iris-virginica'],
#  [4.589117562233506, 'Iris-virginica'],
#  [4.62709412050371, 'Iris-virginica'],
#  [4.649731175025067, 'Iris-virginica'],
#  [4.7148700936505135, 'Iris-virginica'],
#  [4.752893855326457, 'Iris-virginica'],
#  [4.790615826801393, 'Iris-virginica'],
#  [4.806245936279167, 'Iris-virginica'],
#  [4.830113870293329, 'Iris-virginica'],
#  [4.851803788283282, 'Iris-virginica'],
#  [4.873397172404482, 'Iris-virginica'],
#  [4.996999099459595, 'Iris-virginica'],
#  [5.029910535983717, 'Iris-virginica'],
#  [5.047771785649585, 'Iris-virginica'],
#  [5.048762224545736, 'Iris-virginica'],
#  [5.2697248505021586, 'Iris-virginica'],
#  [5.371219600798314, 'Iris-virginica'],
#  [5.372150407425317, 'Iris-virginica'],
#  [5.4972720507539, 'Iris-virginica'],
#  [5.742821606144492, 'Iris-virginica'],
#  [5.822370651203854, 'Iris-virginica'],
#  [5.937171043518959, 'Iris-virginica'],
#  [5.977457653551383, 'Iris-virginica'],
#  [6.220932405998316, 'Iris-virginica']]

# %%
k=5
first_k=[]
for i in range(k):
  first_k.append(distance_cumm[i][1])

# %%
first_k
# Out:
# ['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa']

# %%
from collections import Counter
count = Counter(first_k)

# %%
count
# Out:
# Counter({'Iris-setosa': 5})

# %%
print("Our Final Predicted label is",count.most_common(1)[0][0])
# Out:
# Our Final Predicted label is Iris-setosa
